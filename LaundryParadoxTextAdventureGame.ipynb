# %% [markdown]
# Greetings from the galaxy far far away!
#
# This game is a text adventure called the "Laundry Paradox". Inspired by an episode of the TV series The Big Bang Theory.
# Lorre, C., & Cendrowski, M. .2008, Nov. 10. The Panty Pinata (Season 2, Episode 7). In C. Lorre & B. Prady,
# The Big Bang Theory. Chuck Lorre Productions.
#
# All the stages are based on one of the funniest episodes of a comedy series.
#
# The characters have been changed using another great TV series called How I Met Your Mother.
# Bays, C., & Thomas, C.. (2005-2014).
#
# Some of the in game messages are from Star Trek: Next Generation and Star Wars: The Empire Strikes back.
#
# The goal of the game is for the player to relieve the different funny scenes of the episode and have fun!
#
# Note: As the coding was done, there had been some issues with the transitioning to each stage caused
# by the loops in the code. It had been intermittent but after 48 hrs of debugging, it should be fixed.
# Still, watch out for some issues.
#
# Hope you enjoy the game! Live long and prosper!
#
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⡀⢸⣿⣷⠀⠀⠀⠀⠀⠀⣠⣄⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣧⠈⣿⣿⡆⠀⠀⠀⠀⣼⣿⣿⠀⣤⡀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⡀⢹⣿⣧⠀⠀⠀⣸⣿⣿⠃⣰⣿⣿⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢹⣿⣇⠘⣿⣿⡄⠀⢀⣿⣿⡏⢠⣿⣿⡏⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⣿⣿⡀⢻⣿⣧⠀⣸⣿⡟⢀⣾⣿⡿⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣇⣸⣿⣿⣶⣿⣿⠁⣼⣿⣿⠁⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⢀⣀⣀⣀⠀⠀⠀⢹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠙⢿⣿⣿⣷⣦⣀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡄⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠈⠻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠻⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢿⣿⣿⣿⣿⣿⣿⣿⡟⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠛⠛⠛⠛⠛⠛⠛⠃⠀⠀⠀⠀⠀⠀⠀⠀

# %%
# Importing time function
import time

# Calling Import function for randomnization
import random

# Win Statement
win = 'YOU WIN! LIVE LONG AND PROSPER!\n'

# Lose Statement
lose = 'Do or do not. There is no try. - Yoda. Thank you for playing!\n'

# Defining the Second Stage
def laundry_rm():
    # Printing the scenario and question for the second stage
    print("""Inside the laundry room, Barney saw that all the machines are taken. 
Robin arives and said "Oh no! What are you gonna do?"
Barney: No problem. I'll just do my laundry another night.
Robin: You can try but deep inside your heart you know that 
laundry night is always Saturday night.
Barney: Woman, you are dealing with forces beyond your Ken.

        What do you think is Robin's response? 
            A. Ken? I'm not scared of Ken!
            B. Go tell me to Ken or your mother!
            C. Well your Ken can kiss my Barbie.
            D. Well, tell it to Ken my new boyfriend.\n
              """)

# Defining room for 3rd stage
def barney_apt():
    # Code to show third stage scenario
    print(""" In Barney's apartment, Penny knocks. Barney opens the door and...
Robin: Barney! Where are my clothes?
Barney: You know, when I looked in the window a brazier caught my eye. 
Robin looked in the window and saw...

        Choose the letter what you think Robin saw.
            A. Her clothes hanging and sold by Gunther.
            B. Her clothes hanging by a bar.
            C. Her clothes hanging across the street.
            D. Her clothes hanging in a telephone wire.
            E. Her clothes hanging in a pole.\n""")

# Defining 4th stage
def robin_apt():

    # 4th stage scenario
    print(""" In Robin's apartment, Ted knocks and saw her duct taping different sticks. 
Robin asks...
    "Telephone wires can't electrocute you. Can they?"
    Ted: No. Look! This has to stop!
    Robin: No. No. This is just beginning!

    Ted then hands to Robin _______. And said, it will shorten the war 
    by five years and save millions of lives!

        What did Ted give to Robin? 
            a. Barney's transporter
            b. Barney's kryptonite
            c. Barney's phaser
            d. Barney's light saber \n""")

# Defining 5th stage
def robin_rm():

    # Showing 5th stage scenario and question
    print(""" Outside Robin's room, Barney knocks 3 times. Robin opened the door. 
    Barney, while giving back Robin's laundry, said..
    "Robin, well played! Just remember, ________!"
    
        I wonder what did Barney say to Robin? Is it:
            1. I'm the best there is at what I do.
            2. I Can Do This All Day.
            3. In the the brightest day, in the blackest night, no evil shall escape my sight.
            4. Let those who worship evil's might, beware my power 
            5. With great power comes great responsibility \n""")

# This is the game intro
print(""" Welcome to The Laundry Paradox game!

Imagine that you are the writer of a story. 
You need to make sure that the answers will make the story funny.
It starts after a heated argument between your characters, Robin and Barney who are friends.
You help build the story by guessing the correct answer. 
The diffuclty changes between each of the five stages. 
\n """)

# Key input to start the game
print(input("Once you're ready to play, please hit enter.\n"))

# Giving suspense for the start game.
time.sleep(2)

# Defining the First Room and suing it a start function
def hallway():
    # Printing the first stage with first question
    print(""" In the Hallway, Barney, while carrying his laundry, saw Robin.
                
Barney: Hello!
Robin: Time to do your laundry huh.
Barney: Saturday night. Saturday night is laundry night!
Robin: I know. And if something is to prevent you to do your laundry you may find it unpleasant.

    What should Barney do?\n""" )

    # Providing answer for first answer and creating a variable
    barney_vrb = input('Please type the past tense verb of running.\n')

    # Printing the greeting after the input answer
    print('Great Job! One to beam up Scotty!\n')

    # Implementing 1 second delay for transition
    time.sleep(1)

    # Showing transition message going to next stage
    print('3..2..1 Energize!\n')

    # Delay for transition
    time.sleep(1)

    # Calling next stage function
    laundry_rm()

    # Configuring the correct response
    robin_resp = "C"
    
    # Setting number of tries for stage 2
    max_tries = 3

    for tries in range(max_tries):
        # Encoding the response function input
        response = input('Please key in the letter of your answer.\n')
    
        # Setting up a conditinal IF statement
        if response.upper() == robin_resp:
            
            # Greeting for clearing 2nd stage
            print('Great Job! One to beam up Scotty!\n')
            
            # Time delay for transition
            time.sleep(1)
            
            # Message on transition
            print('3..2..1 Energize!\n')
            
            # Delay before going to 3rd stage
            time.sleep(1)
            
            # setting a break to stop loop
            break
        
        # Creating an if clause to cover other possible answers
        elif response.upper() in ["A", "B", "D"]:  
            
            # Controlling the number of tries
            max_tries -= 1
            
            # Printing message on this stage
            print('Star Destroyer is approaching.\n')
            
            # Printing the number of attempts message
            print(f'You got {max_tries} left. Please try again!\n')
        
        # A cover condition once attempts are exhausted
        elif max_tries == 0: 
            
            # Calling fail function once attempts is zero
            print(f'{lose}')
            
            # Setting a stop function for the loop
            return
        
        # Creating a catch all for anything else
        else:     
            
            # Calling the fail function for everything else
            print(f'{lose}')
            
            # Setting a stop function for the loop
            return

    # Else clause for everything else
    else:
        
    # Message if ELSE statement is triggered
        print(f'{lose}')
        
        # Setting a stop function for the loop
        return

    # Calling out the next stage
    barney_apt()  
    
    # Setting up number of tries
    robin_tries = 3
    
    # Creating a success function
    success = False

    # Creating a list of answers
    robin_saw_opt = [ "A", "B", "C", "D", "E"]

    # Configuring while loop for stage 3
    while robin_tries > 0 and not success:

        # Creating an input function for 3rd stage answer 
        robin_saw = input('Choose the letter what of what you think Robin saw.\n')

        # Setting up IF statement for the correct answer
        if robin_saw == "D":
            print('Great job young padawan! One to beam up Scotty!\n')

            # transition time delay
            time.sleep(1)

            # transition time message
            print('3..2..1 Energize!\n')

            # transition time before next stage
            time.sleep(1)
            
            # Setting up success to control code
            success = True

        # Control for possible inputs other than the correct answer
        elif robin_saw in ["A", "B", "C", "E"]:
            print("The Enterprise cant take off. Try again!\n")

            # Telling Python to deduct number of attempts
            robin_tries -= 1

            # Catch code once number of attemps are exhausted
            if robin_tries == 0:

                # Message in case number of tries is exhausted
                print(f'{lose}')

                # Control to stop the loop
                return
            
            # Capturing code for anything else
            else:

                #  Message to show number of tries left
                print(f'Sorry but the Romulans are winning. {robin_tries} remaining.\n')
                
                # Control to stop the loop
                return

        # ElSE statement to catch undefined inputs
        else:
            # Message to undefined inputs
            print(f'{lose}')

            # Control to stop the loop
            return

    # Calling out the fourth stage
    robin_apt()    
    
    # Setting up correct key input
    barney_thng_key = "Barney's kryptonite"

    # Defining number of attempts for 4th stage
    attempts_count = 3
    
    # Setting success function for stage 4
    success = False

    # Invoking while loop to control stage
    while attempts_count > 0 and not success:

        # Placing the answer input box
        barney_thng = input('Key in just the phrase, as shown above, of the thing that Ted give to Robin.\n')

        # Configuring IF statement to match the answer input
        if barney_thng == barney_thng_key:

            # Clear stage message
            print('Picard: Things are only impossible until they are not. Great work!\n')

            # Clear stage
            input("Set phasers to stun! And hit 'ENTER' for the next level.\n")

            # Clear stage transition message
            print('One to beam up Scotty!\n')

            # Time delay for transition
            time.sleep(1)

            # Transition message
            print('3..2..1 Energize!\n')

            # Defining success rate on this level
            success = True 

        # Catch code for incorrect inputs
        elif barney_thng != barney_thng_key:

            # Counting down number of attempts
            attempts_count -= 1

            # Message for 4th stage number of tries
            print(f"Storm troopers are approaching! You have {attempts_count} tries remaining.\n")

            # IF statement to capture zero attempts
            if attempts_count == 0:

                # Message of lost of attempts
                print(f'{lose}')
                
                # Setting a stop loop function
                return

        # ELSE clause for any other inputs
        else: 

            # Message for other not defined inputs
            print(f'{lose}')
            # Setting a stop loop function
            return

    # Calling out the final stage    
    robin_rm()

    # Creating 5th stage list
    barney_said_opt = [1, 2, 3, 4, 5]

    # Defining attempts for 5th stage
    attempts = 3

    # Invoking WHILE LOOP as attempts control
    while attempts > 0:

        # Programming input option
        barney_said = input(prompt='Type the number of your selected number of choice.>\n')

        # Counting down the number of attempts
        attempts -= 1

        # Configuring a TRY function to control any errors
        try:

            # Ensuring that entry is restrict to number
            barney_said = int(barney_said)

            # Telling Python what to do if entry is not in list
            if barney_said not in [1, 2, 3, 4, 5]:

                # Using RAISE function to catch not listed options
                raise Exception()  

            # Using ELIF to specify correct answer
            elif barney_said == 5:
                print(f'{win}') # this is where win function goes
                # Setting a stop loop function
                return
            
            # Setting message while attempts is used
            elif attempts < 3:
                print(f'Leia: Never underestimate a droid! You have {attempts} left.')

            # Adding second ELIF as attempts control
            elif attempts == 0:
                print(f'{lose}')
                # Setting a stop loop function
                return

            # Safety net for undefined inputs   
            else:
                print(f'{lose}') # this should be a fail function
                # Setting a stop loop function
                return

        except:

            # Controlling attempts in case of not listed inputs in all attempts
            if attempts == 0:
                print(f'Leia: Never underestimate a droid! You have {attempts} left.')
                
                # Setting a stop loop functio
                return
            else:
                print(f'{lose}')
              

 # Putting a code to start call the game and for it to know where to start            
if __name__ == "__main__":
    hallway()
# Out:
# This game is a text adventure called the "Laundry Paradox".
# You help build the story by guessing the correct answer.
# The diffuclty changes between each of its five stages.
# All the scenes are based on one of the funniest episodes of a comedy series.
# Imagine that you are the writer.
# You need to make sure that the answers will make the story funny.
# It starts after a heated argument between friends Robin and Barney.
#
#
# Once you're ready to play, please hit enter.
#
#
#  In the Hallway, Barney, while carrying his laundry, saw Robin.
#
# Barney: Hello!
# Robin: Time to do your laundry huh.
# Barney: Saturday night. Saturday night is laundry night!
# Robin: I know. And if something is to prevent you to do your laundry you may find it unpleasant.
#
#     What should Barney do?
#
# Please type the past tense verb of running.
# ran
# Great Job! One to beam up Scotty!
#
# 3..2..1 Energize!
#
# Inside the laundry room, Barney saw that all the machines are taken.
# ...
